# %% [markdown]
# ### Welcome to the Airbnb Mini Practice Project
#
# Throughout this unit on Python Data Analytics, you'be been introduced the the following powerful libraries:
#
# <li> Matplotlib </li>
# <li> Seaborn </li>
# <li> Pandas </li>
#
# Each of these libraries will enhance your data analysis capabilities.
#
# We've created this challenging exercise to reinforce your understanding of how these libraries work.
#
# Please note, there is a particular emphasis on the Pandas Library. This is the most critical Python library for data analytics. You'll see many similarities between Pandas and Pivot Tables!
#
# <b> The most important thing you can do to build confidence with Python is to practice programming, all the time. This way you will build muscle memory. Don't simply copy the code you've written previously. Write it again and again so you store it in your memory. </b>
#
# <b> As this is a practice exercise, we've included a copy of what the outputs *should* look like for the majority of the questions to give you some guidance. </b>
#
# <H3>  Time to get started! </H3>

# %% [markdown]
# Import the airbnb_2.csv file.
#
# Once you do this, you can start your analysis.
#
# <b> Don't forget to import the libraries you need to read .csv files! </b>

# %% [markdown]
# ### Step 1: <span style="color:green">Import Libraries</span>
# <b> Put your code in the box below. </b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2: <span style="color:green">Import the Airbnb Dataset</span>

# %% [markdown]
# Now that you have the Pandas Libraries imported, it's time to import the Airbnb dataset.
#
# <b> i) Import the Airbnb dataset.
#
# ii) Use .info() function to better understand the variables inside your dataset.
# <p>
#
# <b> Put your code in the box below </b>

# %% [markdown]
# ## My Answer

# %%
df_airbnb= pd.read_csv('airbnb_2.csv')

# %%
df_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
# id                                48895 non-null int64
# name                              48879 non-null object
# host_id                           48895 non-null int64
# host_name                         48874 non-null object
# neighbourhood_group               48895 non-null object
# neighbourhood                     48895 non-null object
# latitude                          48895 non-null float64
# longitude                         48895 non-null float64
# room_type                         48895 non-null object
# price                             48895 non-null int64
# minimum_nights                    48895 non-null int64
# number_of_reviews                 48895 non-null int64
# last_review                       38843 non-null object
# reviews_per_month                 38843 non-null float64
# calculated_host_listings_count    48895 non-null int64
# ...

# %% [markdown]
# ### Step 3: <span style="color:green">Exploring your data with Pandas</span>
#
# The rest of these questions will have you focus on using the following Pandas Skills:
#
# <li> Subsetting a Pandas DataFrame using [] and boolean operators </li>
# <li> Summing up records with value_counts()</li>
# <li> Creating calculated fields </li>
# <li> Group By in Pandas </li>
# <li> Creating Bar Plots with Matplotlib</li>

# %% [markdown]
# <b> i)  Please count how many Airbnb listings are in each of the 5 Neighbourhood Groups (Manhattan, Brooklyn, Queens, Bronx, Staten Island), then identify which Neighbourhood Groups have the greatest number of Airbnb listings. </b>
# <p>
#     <b> Put your code in the box below </b>

# %% [markdown]
# ## My Ans

# %%
df_airbnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df_airbnb.neighbourhood_group.value_counts(sort=True, normalize=True)
# Out:
# Manhattan        0.443011
# Brooklyn         0.411167
# Queens           0.115881
# Bronx            0.022313
# Staten Island    0.007629
# Name: neighbourhood_group, dtype: float64

# %% [markdown]
# We want to focus our attention on the 3 most popular Neighbourhood Groups, by listing volume.
#
# <b> ii) Calculate the percentage of Airbnb listings that each Neighbourhood Group contains. </b>
#
# See this resource for more details <a href = https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html>. </a>
#
# <b> Put your code in the box below. </b>

# %% [markdown]
# ## Springboard

# %%
# Out:
# Manhattan        0.443011
# Brooklyn         0.411167
# Queens           0.115881
# Bronx            0.022313
# Staten Island    0.007629
# Name: neighbourhood_group, dtype: float64

# %% [markdown]
# <b> iii) Create a new calculated field called Revenue and place this into the Airbnb DataFrame. This is to be calculated by using the Price Column x Number_Of_Reviews Columns </b>
#
# <b> Put your code in the box below </b>

# %% [markdown]
# ## My Ans

# %%
df_airbnb['revenue']= df_airbnb['price'] * df_airbnb['number_of_reviews']

# %%
df_airbnb.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19/10/2018               0.21
# 1    225               1                 45  21/05/2019               0.38
#
#    calculated_host_listings_count  availability_365  revenue
# 0                               6               365     1341
# 1                               2               355    10125

# %% [markdown]
# <b> iv) Create a Bar Plot that shows which Neighbourhood Group has the highest average revenues. In order to best
# calculate this, you'd want to consider how you can use the .groupby() syntax to assist you! </b>
#
# If you're stuck, we recommend you go back to this <a href = https://learn.datacamp.com/courses/manipulating-dataframes-with-pandas> DataCamp link</a>. Specifically, Chapter 4 which covers how GROUP BY is used in Pandas.
#
# <b> Put your code in the box below. </b>

# %% [markdown]
# ## My Ans

# %% [markdown]
# ### Method1

# %%
neighbourhood_rev= df_airbnb.groupby('neighbourhood_group').agg({'revenue':'mean'})

# %%
neighbourhood_rev.reset_index(inplace=True)

# %%
neighbourhood_rev
# Out:
#   neighbourhood_group      revenue
# 0               Bronx  1999.439963
# 1            Brooklyn  2927.567400
# 2           Manhattan  3375.960574
# 3              Queens  2400.151077
# 4       Staten Island  2541.764075

# %%
neighbourhood_rev.plot(kind='bar', title= 'Avg revenue by neighbourhood_group')

# %% [markdown]
# ### Method2

# %%
bar_neighbour=sns.catplot(x='neighbourhood_group', y='revenue', data=df_airbnb,kind='bar',ci=None)
bar_neighbour.set_xticklabels(rotation=30)
type(bar_neighbour)
# Out:
# seaborn.axisgrid.FacetGrid

# %% [markdown]
# ### Method3

# %%
fg,ax= plt.subplots()
ax.bar(neighbourhood_rev['neighbourhood_group'], neighbourhood_rev['revenue'])
ax.set_xlabel('Neighbourhood_group')
ax.set_ylabel('Avg_revenue')
ax.set_title('Neighbourhood_Group by Avg_Rev')
# Out:
# Text(0.5, 1.0, 'Neighbourhood_Group by Avg_Rev')

# %% [markdown]
# ### Springboard Ans

# %% [markdown]
# <h3> <span style="color:green">Challenge Questions</span> </h3>

# %% [markdown]
# <b> V) Filter the Airbnb DataFrame to include only the Neighbourhood Groups Manhattan, Brooklyn, and Queens.
#
# Then, identify the top 3 Revenue Generating Neighborhoods within each of the 3 Neighbourhood_Groups. This should give us 9 Overall Rows: 3 of the top generating neighbourhoods within each of the 3 Neighbourhood_Groups </b>
#
# This is a tricky question that will *test* your group-by skills.
#
# We recommend you consider the following:
#
#     condition1 = someDataFrame['someColumn']=='someCondition'
#     condition2 = someDataFrame['someColumn']=='someCondition'
#
#     Step One - Filter the DataFrame using the Conditions
#     filtered_dataframe = someDataFrame[condition1 OR condition 2]
#     #Hint: You might want to look up what the OR symbol in Python is represented as in operator form (i.e. AND (&) )
#
#     Step Two - Group the Data by Neighbourhood_Group and Neighbourhood. Don't forget you're looking to SUM up the Revenues.
#
#     The remaining steps we recommend you think very carefully about.
#
#     You might want to make use of the .reset_index(inplace=True) function to help reset the indexes in
#     your Grouped Up Dataframe...!
#
#
# <b> Put your code in the box below. </b>

# %% [markdown]
# ## My Ans

# %%
df_airbnb.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19/10/2018               0.21
# 1    225               1                 45  21/05/2019               0.38
#
#    calculated_host_listings_count  availability_365  revenue
# 0                               6               365     1341
# 1                               2               355    10125

# %%
man_hat_queens= df_airbnb[df_airbnb['neighbourhood_group'].isin(['Manhattan','Brooklyn','Queens'])]

# %%
man_hat_queens.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19/10/2018               0.21
# 1    225               1                 45  21/05/2019               0.38
#
#    calculated_host_listings_count  availability_365  revenue
# 0                               6               365     1341
# 1                               2               355    10125

# %%
gp_df= man_hat_queens.groupby(['neighbourhood_group','neighbourhood']).agg({'revenue':'sum'})

# %%
gp_df
# Out:
#                                           revenue
# neighbourhood_group neighbourhood
# Brooklyn            Bath Beach              33486
#                     Bay Ridge              310019
#                     Bedford-Stuyvesant   12352457
#                     Bensonhurst            159780
#                     Bergen Beach            22485
#                     Boerum Hill            620677
#                     Borough Park           148901
#                     Brighton Beach         115866
#                     Brooklyn Heights       511129
#                     Brownsville            133189
#                     Bushwick              4762224
#                     Canarsie               504783
#                     Carroll Gardens       1079562
#                     Clinton Hill          2318370
#                     Cobble Hill            442411
#                     Columbia St             85605
#                     Coney Island            40368
# ...

# %%
type(gp_df)
# Out:
# pandas.core.frame.DataFrame

# %%
sort_gp_df= gp_df.sort_values('revenue', ascending=False)

# %%
type(sort_gp_df)
# Out:
# pandas.core.frame.DataFrame

# %%
sort_gp_df.reset_index(inplace=True)

# %%
sort_gp_df
# Out:
#     neighbourhood_group              neighbourhood   revenue
# 0              Brooklyn               Williamsburg  12389011
# 1              Brooklyn         Bedford-Stuyvesant  12352457
# 2             Manhattan                     Harlem   8598692
# 3             Manhattan             Hell's Kitchen   8238991
# 4             Manhattan               East Village   7574535
# 5             Manhattan            Upper West Side   5984268
# 6             Manhattan            Upper East Side   4983129
# 7             Manhattan                    Chelsea   4807493
# 8              Brooklyn                   Bushwick   4762224
# 9             Manhattan                East Harlem   4202161
# 10             Brooklyn              Crown Heights   4087368
# 11            Manhattan                    Midtown   4085103
# 12            Manhattan            Lower East Side   3845856
# 13            Manhattan               West Village   3482156
# ...

# %%
sort_gp_df.groupby(['neighbourhood_group']).head(3)
# Out:
#    neighbourhood_group       neighbourhood   revenue
# 0             Brooklyn        Williamsburg  12389011
# 1             Brooklyn  Bedford-Stuyvesant  12352457
# 2            Manhattan              Harlem   8598692
# 3            Manhattan      Hell's Kitchen   8238991
# 4            Manhattan        East Village   7574535
# 8             Brooklyn            Bushwick   4762224
# 17              Queens             Astoria   1880840
# 28              Queens    Long Island City   1374945
# 33              Queens            Flushing   1140450

# %% [markdown]
# <b> VI) Filter the Airbnb Dataframe to include only the top 3 Neighbroos within each neighbourhood_group.
#
# After doing this, identify the top average revenue-generating room-type for each of the nine neighbourhoods and plot this  in a Bar Chart.</b>
#
# This is a tricky question that will *test* your group-by skills. Think back to the previous question and how you approached this; you can approach this in a similar manner.
#
# We recommend you consider the following:
#
#     condition1 = someDataFrame['someColumn']=='someCondition'
#     condition2 = someDataFrame['someColumn']=='someCondition'
#
#     Step One - Filter the Dataframe using the Conditions
#     filtered_dataframe = someDataFrame[condition1 OR condition 2]
#     #Hint: You might want to look up what the OR symbol in Python is represented as in operator form (i.e. AND (&) )
#
#     Step Two - Group the Data by Neighbourhood_Group and Neighbourhood. Don't forget you're looking to SUM up the Revenues.
#
#     The remaining steps we recommend you think very carefully about.
#
#     You might want to make use of the .reset_index(inplace=True) function to help reset the indexes in
#     your Grouped Up Dataframe...!
#
#
#  <b> Put your code in the box below. </b>

# %% [markdown]
# ## My Ans (a)

# %%
top_three_nei= df_airbnb.groupby(['neighbourhood_group','neighbourhood']).agg({'revenue':sum})

# %%
top_three_nei= top_three_nei.sort_values('revenue',ascending=False)

# %%
top_three_nei.head()
# Out:
#                                          revenue
# neighbourhood_group neighbourhood
# Brooklyn            Williamsburg        12389011
#                     Bedford-Stuyvesant  12352457
# Manhattan           Harlem               8598692
#                     Hell's Kitchen       8238991
#                     East Village         7574535

# %%
top_three_nei= top_three_nei.reset_index()

# %%
top_three_nei.head()
# Out:
#   neighbourhood_group       neighbourhood   revenue
# 0            Brooklyn        Williamsburg  12389011
# 1            Brooklyn  Bedford-Stuyvesant  12352457
# 2           Manhattan              Harlem   8598692
# 3           Manhattan      Hell's Kitchen   8238991
# 4           Manhattan        East Village   7574535

# %%
top_three_nei= top_three_nei.groupby('neighbourhood_group').head(3)

# %%
top_three_nei
# Out:
#     neighbourhood_group       neighbourhood   revenue
# 0              Brooklyn        Williamsburg  12389011
# 1              Brooklyn  Bedford-Stuyvesant  12352457
# 2             Manhattan              Harlem   8598692
# 3             Manhattan      Hell's Kitchen   8238991
# 4             Manhattan        East Village   7574535
# 8              Brooklyn            Bushwick   4762224
# 17               Queens             Astoria   1880840
# 28               Queens    Long Island City   1374945
# 33               Queens            Flushing   1140450
# 73        Staten Island          St. George    193877
# 74                Bronx          Mott Haven    193514
# 83        Staten Island       Tompkinsville    155696
# 84                Bronx            Allerton    152994
# 87                Bronx           Concourse    145787
# 104       Staten Island           Stapleton     86499

# %% [markdown]
# ## (b)

# %%
df_airbnb.head(2)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
# 1  2595               Skylit Midtown Castle     2845  Jennifer
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
#
#    price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0    149               1                  9  19/10/2018               0.21
# 1    225               1                 45  21/05/2019               0.38
#
#    calculated_host_listings_count  availability_365  revenue
# 0                               6               365     1341
# 1                               2               355    10125

# %%
nei_gp_df= df_airbnb.groupby(['neighbourhood_group','neighbourhood','room_type']).agg({'revenue':'mean'})

# %%
nei_gp_df
# Out:
#                                                             revenue
# neighbourhood_group neighbourhood     room_type
# Bronx               Allerton          Entire home/apt   6179.375000
#                                       Private room      2081.692308
#                     Baychester        Entire home/apt   8618.666667
#                                       Private room       370.500000
#                     Belmont           Entire home/apt   5545.000000
#                                       Private room       595.736842
#                                       Shared room         49.000000
#                     Bronxdale         Entire home/apt    678.500000
#                                       Private room      1529.500000
#                                       Shared room        228.000000
#                     Castle Hill       Entire home/apt   2345.000000
#                                       Private room         0.000000
# ...

# %%
nei_gp_df= nei_gp_df.sort_values('revenue', ascending=False)

# %%
nei_gp_df
# Out:
#                                                               revenue
# neighbourhood_group neighbourhood       room_type
# Queens              Bay Terrace         Entire home/apt  14309.666667
# Staten Island       Silver Lake         Entire home/apt  11760.000000
# Manhattan           Battery Park City   Shared room      11275.000000
# Brooklyn            Vinegar Hill        Shared room       9250.000000
# Staten Island       Huguenot            Entire home/apt   9026.666667
#                     Castleton Corners   Entire home/apt   9015.500000
# Bronx               Baychester          Entire home/apt   8618.666667
# Staten Island       Eltingville         Private room      8120.000000
# Bronx               East Morrisania     Entire home/apt   7853.333333
# Manhattan           Flatiron District   Entire home/apt   7839.584615
# Staten Island       Clifton             Entire home/apt   7380.000000
# Manhattan           Nolita              Entire home/apt   7355.715152
# ...

# %%
nei_gp_df= nei_gp_df.reset_index()

# %%
nei_gp_df
# Out:
#     neighbourhood_group        neighbourhood        room_type       revenue
# 0                Queens          Bay Terrace  Entire home/apt  14309.666667
# 1         Staten Island          Silver Lake  Entire home/apt  11760.000000
# 2             Manhattan    Battery Park City      Shared room  11275.000000
# 3              Brooklyn         Vinegar Hill      Shared room   9250.000000
# 4         Staten Island             Huguenot  Entire home/apt   9026.666667
# 5         Staten Island    Castleton Corners  Entire home/apt   9015.500000
# 6                 Bronx           Baychester  Entire home/apt   8618.666667
# 7         Staten Island          Eltingville     Private room   8120.000000
# 8                 Bronx      East Morrisania  Entire home/apt   7853.333333
# 9             Manhattan    Flatiron District  Entire home/apt   7839.584615
# 10        Staten Island              Clifton  Entire home/apt   7380.000000
# ...

# %%
nei_gp_df= nei_gp_df.groupby('neighbourhood_group').head(3)

# %%
nei_gp_df
# Out:
#    neighbourhood_group      neighbourhood        room_type       revenue
# 0               Queens        Bay Terrace  Entire home/apt  14309.666667
# 1        Staten Island        Silver Lake  Entire home/apt  11760.000000
# 2            Manhattan  Battery Park City      Shared room  11275.000000
# 3             Brooklyn       Vinegar Hill      Shared room   9250.000000
# 4        Staten Island           Huguenot  Entire home/apt   9026.666667
# 5        Staten Island  Castleton Corners  Entire home/apt   9015.500000
# 6                Bronx         Baychester  Entire home/apt   8618.666667
# 8                Bronx    East Morrisania  Entire home/apt   7853.333333
# 9            Manhattan  Flatiron District  Entire home/apt   7839.584615
# 11           Manhattan             Nolita  Entire home/apt   7355.715152
# 12              Queens   South Ozone Park  Entire home/apt   7043.500000
# 13            Brooklyn              DUMBO     Private room   7013.076923
# ...

# %%
nei_gp_df['nei_room']= nei_gp_df['neighbourhood']+','+nei_gp_df['room_type']
nei_gp_df.rename({'revenue':'avg_revnue'}, inplace=True)

# %%
nei_gp_df
# Out:
#    neighbourhood_group      neighbourhood        room_type       revenue  \
# 0               Queens        Bay Terrace  Entire home/apt  14309.666667
# 1        Staten Island        Silver Lake  Entire home/apt  11760.000000
# 2            Manhattan  Battery Park City      Shared room  11275.000000
# 3             Brooklyn       Vinegar Hill      Shared room   9250.000000
# 4        Staten Island           Huguenot  Entire home/apt   9026.666667
# 5        Staten Island  Castleton Corners  Entire home/apt   9015.500000
# 6                Bronx         Baychester  Entire home/apt   8618.666667
# 8                Bronx    East Morrisania  Entire home/apt   7853.333333
# 9            Manhattan  Flatiron District  Entire home/apt   7839.584615
# 11           Manhattan             Nolita  Entire home/apt   7355.715152
# 12              Queens   South Ozone Park  Entire home/apt   7043.500000
# 13            Brooklyn              DUMBO     Private room   7013.076923
# ...

# %% [markdown]
# ### Bar Plot using Seaborn

# %%
nei_gp_bar= sns.catplot(x='nei_room', y='revenue',data=nei_gp_df, kind='bar')
nei_gp_bar.fig.suptitle('   Popular Airbnb Neighbourhoods by Room Type')
nei_gp_bar.set_xticklabels(rotation=90)

# %% [markdown]
# ### Bar Plot using Pandas Visualization

# %%
ax=nei_gp_df.plot(x='nei_room', y='revenue',kind='bar', title='Populay Airbnb Neighbourhoods by RoomType')
ax.set_ylabel('Avg_revenue')
# Out:
# Text(0, 0.5, 'Avg_revenue')

# %% [markdown]
# ### Bar Plot using MatplotLib

# %%
fg, ax= plt.subplots()
ax.bar(nei_gp_df['nei_room'],nei_gp_df['revenue'])
ax.set_xticklabels(nei_gp_df['nei_room'],rotation=90)
ax.set_xlabel('Neighourhood_RoomType')
ax.set_ylabel('Avg Revenue')
ax.set_title('Populay Airbnb Neighbourhoods by RoomType')
# Out:
# Text(0.5, 1.0, 'Populay Airbnb Neighbourhoods by RoomType')

# %% [markdown]
# ### Springboard Ans for the last question
